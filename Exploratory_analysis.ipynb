# %% [markdown]
# Import libraries

# %%
import os
import pandas as pd
import geopandas as gpd

# %% [markdown]
# Define paths

# %%
SCRIPT_CWD= os.getcwd()
ROOT_DIR= os.path.dirname(SCRIPT_CWD)
CROWNS_DIR= ROOT_DIR/ "shapefiles"/ "allergenic_crowns"
POINTS_DIR= ROOT_DIR/ "shapefiles"/ "allergenic_points"
RGB_DIR= ROOT_DIR/ "rgb_tiles"
CIR_DIR= ROOT_DIR/ "cir_tiles"
# Out:
# Running cells with 'venv (Python 3.13.1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/48669/Desktop/Spatial engineering/Master thesis/Data/thesis_visualization/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# # Spatial distribution of species overlay with rgb tiles

# %%
crowns_df= gpd.read_csv(CROWNS_DIR)

# %% [markdown]
# # Quantitative distribution of species

# %% [markdown]
# # Species crown size violion plot for example

# %% [markdown]
# # Number of crown with overlap more than 50% and show them

# %% [markdown]
# # Tree crown bands values- means from pixels inside the crown, stv

# %% [markdown]
# # Texture

# %% [markdown]
# # Bounding box mean, min, max size for anchor sizes
